# %%
import fastf1

# %%
session = fastf1.get_session(2021, 7, 'Q')
session
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (161.99 MB) C:\Users\Janhavi\AppData\Local\Temp\fastf1
# 2021 Season Round 7: French Grand Prix - Qualifying

# %%
session.date
# Out:
# Timestamp('2021-06-19 13:00:00')

# %%
session.event
# Out:
# RoundNumber                                                     7
# Country                                                    France
# Location                                             Le Castellet
# OfficialEventName    FORMULA 1 EMIRATES GRAND PRIX DE FRANCE 2021
# EventDate                                     2021-06-20 00:00:00
# EventName                                       French Grand Prix
# EventFormat                                          conventional
# Session1                                               Practice 1
# Session1Date                            2021-06-18 11:30:00+02:00
# Session1DateUtc                               2021-06-18 09:30:00
# Session2                                               Practice 2
# Session2Date                            2021-06-18 15:00:00+02:00
# Session2DateUtc                               2021-06-18 13:00:00
# Session3                                               Practice 3
# ...

# %%
events = fastf1.get_event(2023, 'Spain')
events
# Out:
# RoundNumber                                                 7
# Country                                                 Spain
# Location                                            Barcelona
# OfficialEventName    FORMULA 1 AWS GRAN PREMIO DE ESPAÑA 2023
# EventDate                                 2023-06-04 00:00:00
# EventName                                  Spanish Grand Prix
# EventFormat                                      conventional
# Session1                                           Practice 1
# Session1Date                        2023-06-02 13:30:00+02:00
# Session1DateUtc                           2023-06-02 11:30:00
# Session2                                           Practice 2
# Session2Date                        2023-06-02 17:00:00+02:00
# Session2DateUtc                           2023-06-02 15:00:00
# Session3                                           Practice 3
# Session3Date                        2023-06-03 12:30:00+02:00
# ...

# %%
events['EventName']
# Out:
# 'Spanish Grand Prix'

# %%
schedule = fastf1.get_event_schedule(2025)
schedule.head()
# Out:
#    RoundNumber    Country   Location  \
# 0            0    Bahrain     Sakhir
# 1            1  Australia  Melbourne
# 2            2      China   Shanghai
# 3            3      Japan     Suzuka
# 4            4    Bahrain     Sakhir
#
#                                    OfficialEventName  EventDate  \
# 0           FORMULA 1 ARAMCO PRE-SEASON TESTING 2025 2025-02-28
# 1  FORMULA 1 LOUIS VUITTON AUSTRALIAN GRAND PRIX ... 2025-03-16
# 2         FORMULA 1 HEINEKEN CHINESE GRAND PRIX 2025 2025-03-23
# 3         FORMULA 1 LENOVO JAPANESE GRAND PRIX 2025  2025-04-06
# 4         FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2025 2025-04-13
#
#                EventName        EventFormat    Session1  \
# 0     Pre-Season Testing            testing  Practice 1
# 1  Australian Grand Prix       conventional  Practice 1
# 2     Chinese Grand Prix  sprint_qualifying  Practice 1
# 3    Japanese Grand Prix       conventional  Practice 1
# 4     Bahrain Grand Prix       conventional  Practice 1
#
# ...

# %%
fastf1.get_events_remaining()
# Out:
#     RoundNumber               Country     Location  \
# 20           20                Mexico  Mexico City
# 21           21                Brazil    São Paulo
# 22           22         United States    Las Vegas
# 23           23                 Qatar       Lusail
# 24           24  United Arab Emirates   Yas Island
#
#                                     OfficialEventName  EventDate  \
# 20  FORMULA 1 GRAN PREMIO DE LA CIUDAD DE MÉXICO 2025 2025-10-26
# 21  FORMULA 1 MSC CRUISES GRANDE PRÊMIO DE SÃO PAU... 2025-11-09
# 22       FORMULA 1 HEINEKEN LAS VEGAS GRAND PRIX 2025 2025-11-22
# 23      FORMULA 1 QATAR AIRWAYS QATAR GRAND PRIX 2025 2025-11-30
# 24  FORMULA 1 ETIHAD AIRWAYS ABU DHABI GRAND PRIX ... 2025-12-07
#
#                  EventName        EventFormat    Session1  \
# 20  Mexico City Grand Prix       conventional  Practice 1
# 21    São Paulo Grand Prix  sprint_qualifying  Practice 1
# 22    Las Vegas Grand Prix       conventional  Practice 1
# ...

# %%
schedule.get_event_by_round(12)
# Out:
# RoundNumber                                                       12
# Country                                               United Kingdom
# Location                                                 Silverstone
# OfficialEventName    FORMULA 1 QATAR AIRWAYS BRITISH GRAND PRIX 2025
# EventDate                                        2025-07-06 00:00:00
# EventName                                         British Grand Prix
# EventFormat                                             conventional
# Session1                                                  Practice 1
# Session1Date                               2025-07-04 12:30:00+01:00
# Session1DateUtc                                  2025-07-04 11:30:00
# Session2                                                  Practice 2
# Session2Date                               2025-07-04 16:00:00+01:00
# Session2DateUtc                                  2025-07-04 15:00:00
# Session3                                                  Practice 3
# ...

# %%
events.get_practice(1)
# Out:
# 2023 Season Round 7: Spanish Grand Prix - Practice 1

# %%
session._load_drivers_results()
# Out:
# req            INFO 	Using cached data for driver_info

# %%
session.load()
# Out:
# core           INFO 	Loading data for French Grand Prix - Qualifying [v3.6.1]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '77', '11', '55', '10', '16', '4', '14', '3', '31', '5', '99', '63', '47', '6', '7', '9', '18', '22']

# %%
import matplotlib.pyplot as plt

lap = session.laps.pick_driver('VER').pick_fastest()
telemetry = lap.get_telemetry()

plt.plot(telemetry['Distance'], telemetry['Speed'])
plt.xlabel('Distance (m)')
plt.ylabel('Speed (km/h)')
plt.title('Verstappen fastest lap speed')
plt.show()
# Out:
# c:\Users\Janhavi\AppData\Local\Programs\Python\Python312\Lib\site-packages\fastf1\core.py:3183: FutureWarning: pick_driver is deprecated and will be removed in a future release. Use pick_drivers instead.
#   warnings.warn(("pick_driver is deprecated and will be removed"

# %%
session.laps.head()
# Out:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 00:17:35.479000    GAS           10                    NaT
# 1 0 days 00:27:42.702000    GAS           10                    NaT
# 2 0 days 00:30:15.038000    GAS           10                    NaT
# 3 0 days 00:31:46.936000    GAS           10 0 days 00:01:31.898000
# 4 0 days 00:34:20.695000    GAS           10                    NaT
#
#    LapNumber  Stint             PitOutTime              PitInTime  \
# 0        1.0    1.0 0 days 00:14:47.810000                    NaT
# 1        2.0    1.0                    NaT 0 days 00:19:40.614000
# 2        3.0    2.0 0 days 00:27:42.702000                    NaT
# 3        4.0    2.0                    NaT                    NaT
# 4        5.0    2.0                    NaT                    NaT
#
#              Sector1Time            Sector2Time  ... FreshTyre        Team  \
# 0 0 days 00:00:48.895000 0 days 00:00:46.957000  ...      True  AlphaTauri
# ...

# %%
session.laps.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate'],
#       dtype='object')

# %%
session.laps.pick_fastest()
# Out:
# Time                      0 days 01:25:25.050000
# Driver                                       VER
# DriverNumber                                  33
# LapTime                   0 days 00:01:29.990000
# LapNumber                                   15.0
# Stint                                        6.0
# PitOutTime                                   NaT
# PitInTime                                    NaT
# Sector1Time               0 days 00:00:22.405000
# Sector2Time               0 days 00:00:27.388000
# Sector3Time               0 days 00:00:40.197000
# Sector1SessionTime        0 days 01:24:17.465000
# Sector2SessionTime        0 days 01:24:44.853000
# Sector3SessionTime        0 days 01:25:25.050000
# SpeedI1                                    126.0
# SpeedI2                                    284.0
# SpeedFL                                    303.0
# SpeedST                                    328.0
# IsPersonalBest                              True
# ...
